# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('AQI By State 1980-2022.csv')
data
# Out:
#                                              Geo_Loc  Year          State  \
# 0       POINT (-86.63186076199969 32.84057112200048)  1980        Alabama
# 1      POINT (-147.72205903599973 64.84507995700051)  1980         Alaska
# 2     POINT (-111.76381127699972 34.865970280000454)  1980        Arizona
# 3       POINT (-92.27449074299966 34.74865012400045)  1980       Arkansas
# 4      POINT (-120.99999953799971 37.63864012300047)  1980     California
# ...                                              ...   ...            ...
# 2188    POINT (-78.45789046299967 37.54268067400045)  2022       Virginia
# 2189   POINT (-120.47001078999972 47.52227862900048)  2022     Washington
# 2190    POINT (-80.71264013499967 38.66551020200046)  2022  West Virginia
# 2191    POINT (-89.81637074199966 44.39319117400049)  2022      Wisconsin
# 2192   POINT (-108.10983035299967 43.23554134300048)  2022        Wyoming
#
#        Pop_Est  TTL_Cnty  Cnty_Rpt  Dys_w_AQI  Dys_NM  Dys_Blw_Thr  \
# ...

# %% [markdown]
# # 1. Display Top 10 Rows of The Dataset

# %%
data.head(10)
# Out:
#                                           Geo_Loc  Year                 State  \
# 0    POINT (-86.63186076199969 32.84057112200048)  1980               Alabama
# 1   POINT (-147.72205903599973 64.84507995700051)  1980                Alaska
# 2  POINT (-111.76381127699972 34.865970280000454)  1980               Arizona
# 3    POINT (-92.27449074299966 34.74865012400045)  1980              Arkansas
# 4   POINT (-120.99999953799971 37.63864012300047)  1980            California
# 5  POINT (-106.13361092099967 38.843840757000464)  1980              Colorado
# 6    POINT (-72.64984095199964 41.56266102000046)  1980           Connecticut
# 7   POINT (-75.57774116799965 39.008830667000495)  1980              Delaware
# 8                    POINT (-77.036871 38.907192)  1980  District Of Columbia
# 9   POINT (-81.92896053899966 28.932040377000476)  1980               Florida
#
#     Pop_Est  TTL_Cnty  Cnty_Rpt  Dys_w_AQI  Dys_NM  Dys_Blw_Thr  Dys_Abv_Thr  \
# ...

# %% [markdown]
# # 2.Check Last 10 Rows of The Dataset

# %%
data.tail(10)
# Out:
#                                              Geo_Loc  Year          State  \
# 2183   POINT (-100.3735306369997 44.353130053000484)  2022   South Dakota
# 2184    POINT (-85.77449091399967 35.68094058000048)  2022      Tennessee
# 2185   POINT (-99.42677020599967 31.827240407000488)  2022          Texas
# 2186  POINT (-111.58713063499971 39.360700171000474)  2022           Utah
# 2187    POINT (-72.51764079099962 43.62538123900049)  2022        Vermont
# 2188    POINT (-78.45789046299967 37.54268067400045)  2022       Virginia
# 2189   POINT (-120.47001078999972 47.52227862900048)  2022     Washington
# 2190    POINT (-80.71264013499967 38.66551020200046)  2022  West Virginia
# 2191    POINT (-89.81637074199966 44.39319117400049)  2022      Wisconsin
# 2192   POINT (-108.10983035299967 43.23554134300048)  2022        Wyoming
#
#        Pop_Est  TTL_Cnty  Cnty_Rpt  Dys_w_AQI  Dys_NM  Dys_Blw_Thr  \
# 2183    909824        66        10       1802    1848         1800
# ...

# %% [markdown]
# # 3.Find Shape of Our Dataset(Nuber of Rows AndNumber of columns)

# %%
data.shape
# Out:
# (2193, 24)

# %%
print ("Number of Rows",data.shape[0])
print ("Number of columns",data.shape[1])
# Out:
# Number of Rows 2193
# Number of columns 24

# %% [markdown]
# # 4. Getting information AboutOur Dataset Like Total Nuberr Rows,Total Number of Columns, Datatypes of Each Column and MemoryRequuirment

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2193 entries, 0 to 2192
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Geo_Loc                              2193 non-null   object
#  1   Year                                 2193 non-null   int64
#  2   State                                2193 non-null   object
#  3   Pop_Est                              2193 non-null   int64
#  4   TTL_Cnty                             2193 non-null   int64
#  5   Cnty_Rpt                             2193 non-null   int64
#  6   Dys_w_AQI                            2193 non-null   int64
#  7   Dys_NM                               2193 non-null   int64
#  8   Dys_Blw_Thr                          2193 non-null   int64
#  9   Dys_Abv_Thr                          2193 non-null   int64
#  10  Good Days                            2193 non-null   int64
# ...

# %% [markdown]
# # 5.Check missing Values In The Dataset

# %%
print("Any missing va;ues?",data.isnull().values.any())
# Out:
# Any missing va;ues? False

# %%
data.isnull()
# Out:
#       Geo_Loc   Year  State  Pop_Est  TTL_Cnty  Cnty_Rpt  Dys_w_AQI  Dys_NM  \
# 0       False  False  False    False     False     False      False   False
# 1       False  False  False    False     False     False      False   False
# 2       False  False  False    False     False     False      False   False
# 3       False  False  False    False     False     False      False   False
# 4       False  False  False    False     False     False      False   False
# ...       ...    ...    ...      ...       ...       ...        ...     ...
# 2188    False  False  False    False     False     False      False   False
# 2189    False  False  False    False     False     False      False   False
# 2190    False  False  False    False     False     False      False   False
# 2191    False  False  False    False     False     False      False   False
# 2192    False  False  False    False     False     False      False   False
#
# ...

# %%
data.isnull().sum()
# Out:
# Geo_Loc                                0
# Year                                   0
# State                                  0
# Pop_Est                                0
# TTL_Cnty                               0
# Cnty_Rpt                               0
# Dys_w_AQI                              0
# Dys_NM                                 0
# Dys_Blw_Thr                            0
# Dys_Abv_Thr                            0
# Good Days                              0
# Moderate Days                          0
# Unhealthy for Sensitive Groups Days    0
# Unhealthy Days                         0
# Very Unhealthy Days                    0
# Hazardous Days                         0
# Max AQI                                0
# 90th Percentile AQI                    0
# Median AQI                             0
# Days CO                                0
# Days NO2                               0
# Days Ozone                             0
# Days PM2.5                             0
# ...

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
per_missing = data.isnull().sum() * 100 / len (data)
per_missing
# Out:
# Geo_Loc                                0.0
# Year                                   0.0
# State                                  0.0
# Pop_Est                                0.0
# TTL_Cnty                               0.0
# Cnty_Rpt                               0.0
# Dys_w_AQI                              0.0
# Dys_NM                                 0.0
# Dys_Blw_Thr                            0.0
# Dys_Abv_Thr                            0.0
# Good Days                              0.0
# Moderate Days                          0.0
# Unhealthy for Sensitive Groups Days    0.0
# Unhealthy Days                         0.0
# Very Unhealthy Days                    0.0
# Hazardous Days                         0.0
# Max AQI                                0.0
# 90th Percentile AQI                    0.0
# Median AQI                             0.0
# Days CO                                0.0
# Days NO2                               0.0
# Days Ozone                             0.0
# ...

# %% [markdown]
# # 6.Drop All missing Values

# %%
data.dropna(axis=0)
# Out:
#                                              Geo_Loc  Year          State  \
# 0       POINT (-86.63186076199969 32.84057112200048)  1980        Alabama
# 1      POINT (-147.72205903599973 64.84507995700051)  1980         Alaska
# 2     POINT (-111.76381127699972 34.865970280000454)  1980        Arizona
# 3       POINT (-92.27449074299966 34.74865012400045)  1980       Arkansas
# 4      POINT (-120.99999953799971 37.63864012300047)  1980     California
# ...                                              ...   ...            ...
# 2188    POINT (-78.45789046299967 37.54268067400045)  2022       Virginia
# 2189   POINT (-120.47001078999972 47.52227862900048)  2022     Washington
# 2190    POINT (-80.71264013499967 38.66551020200046)  2022  West Virginia
# 2191    POINT (-89.81637074199966 44.39319117400049)  2022      Wisconsin
# 2192   POINT (-108.10983035299967 43.23554134300048)  2022        Wyoming
#
#        Pop_Est  TTL_Cnty  Cnty_Rpt  Dys_w_AQI  Dys_NM  Dys_Blw_Thr  \
# ...

# %% [markdown]
# # 7.Drop For Duplicate Data

# %%
dup_data=data.duplicated().any()

# %%
print("Are there  any duplicate values?",dup_data)
# Out:
# Are there  any duplicate values? False

# %%
data=data.drop_duplicates()
data
# Out:
#                                              Geo_Loc  Year          State  \
# 0       POINT (-86.63186076199969 32.84057112200048)  1980        Alabama
# 1      POINT (-147.72205903599973 64.84507995700051)  1980         Alaska
# 2     POINT (-111.76381127699972 34.865970280000454)  1980        Arizona
# 3       POINT (-92.27449074299966 34.74865012400045)  1980       Arkansas
# 4      POINT (-120.99999953799971 37.63864012300047)  1980     California
# ...                                              ...   ...            ...
# 2188    POINT (-78.45789046299967 37.54268067400045)  2022       Virginia
# 2189   POINT (-120.47001078999972 47.52227862900048)  2022     Washington
# 2190    POINT (-80.71264013499967 38.66551020200046)  2022  West Virginia
# 2191    POINT (-89.81637074199966 44.39319117400049)  2022      Wisconsin
# 2192   POINT (-108.10983035299967 43.23554134300048)  2022        Wyoming
#
#        Pop_Est  TTL_Cnty  Cnty_Rpt  Dys_w_AQI  Dys_NM  Dys_Blw_Thr  \
# ...

# %% [markdown]
# # 8.Get Overall Statistics About The DataFrame

# %%
data.describe(include='all')
# Out:
#                                              Geo_Loc         Year    State  \
# count                                           2193  2193.000000     2193
# unique                                            51          NaN       51
# top     POINT (-86.63186076199969 32.84057112200048)          NaN  Alabama
# freq                                              43          NaN       43
# mean                                             NaN  2001.000000      NaN
# std                                              NaN    12.412504      NaN
# min                                              NaN  1980.000000      NaN
# 25%                                              NaN  1990.000000      NaN
# 50%                                              NaN  2001.000000      NaN
# 75%                                              NaN  2012.000000      NaN
# max                                              NaN  2022.000000      NaN
#
# ...

# %% [markdown]
# # 9.Display title of The Moving Having Runtie>= 180 Minutes

# %%
data.columns
# Out:
# Index(['Geo_Loc', 'Year', 'State', 'Pop_Est', 'TTL_Cnty', 'Cnty_Rpt',
#        'Dys_w_AQI', 'Dys_NM', 'Dys_Blw_Thr', 'Dys_Abv_Thr', 'Good Days',
#        'Moderate Days', 'Unhealthy for Sensitive Groups Days',
#        'Unhealthy Days', 'Very Unhealthy Days', 'Hazardous Days', 'Max AQI',
#        '90th Percentile AQI', 'Median AQI', 'Days CO', 'Days NO2',
#        'Days Ozone', 'Days PM2.5', 'Days PM10'],
#       dtype='object')

# %%
data['TTL_Cnty']>=180
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2188    False
# 2189    False
# 2190    False
# 2191    False
# 2192    False
# Name: TTL_Cnty, Length: 2193, dtype: bool

# %%
data[data['TTL_Cnty']>=180]
# Out:
#                                             Geo_Loc  Year  State   Pop_Est  \
# 43    POINT (-99.42677020599967 31.827240407000488)  1980  Texas  14338208
# 94    POINT (-99.42677020599967 31.827240407000488)  1981  Texas  14746318
# 145   POINT (-99.42677020599967 31.827240407000488)  1982  Texas  15331408
# 196   POINT (-99.42677020599967 31.827240407000488)  1983  Texas  15751674
# 247   POINT (-99.42677020599967 31.827240407000488)  1984  Texas  16007088
# 298   POINT (-99.42677020599967 31.827240407000488)  1985  Texas  16272722
# 349   POINT (-99.42677020599967 31.827240407000488)  1986  Texas  16561103
# 400   POINT (-99.42677020599967 31.827240407000488)  1987  Texas  16621767
# 451   POINT (-99.42677020599967 31.827240407000488)  1988  Texas  16667040
# 502   POINT (-99.42677020599967 31.827240407000488)  1989  Texas  16806729
# 553   POINT (-99.42677020599967 31.827240407000488)  1990  Texas  17056755
# ...

# %%
data[data['TTL_Cnty']>=180]['Pop_Est']
# Out:
# 43      14338208
# 94      14746318
# 145     15331408
# 196     15751674
# 247     16007088
# 298     16272722
# 349     16561103
# 400     16621767
# 451     16667040
# 502     16806729
# 553     17056755
# 604     17398005
# 655     17759738
# 706     18161612
# 757     18564062
# 808     18958751
# 859     19340342
# 910     19740317
# 961     20157531
# 1012    20558220
# 1063    20944499
# 1114    21319622
# 1165    21690325
# 1216    22030931
# 1267    22394023
# 1318    22778123
# 1369    23359580
# 1420    23831983
# 1471    24309039
# 1522    24801761
# 1573    25241897
# 1624    25645504
# 1675    26084120
# 1726    26479646
# 1777    26963092
# 1828    27468531
# 1879    27914064
# 1930    28291024
# 1981    28624564
# 2032    28986794
# 2083    29232474
# 2134    29558864
# 2185    30029572
# Name: Pop_Est, dtype: int64

# %% [markdown]
# # 10.Higthest Average

# %%
data.columns
# Out:
# Index(['Geo_Loc', 'Year', 'State', 'Pop_Est', 'TTL_Cnty', 'Cnty_Rpt',
#        'Dys_w_AQI', 'Dys_NM', 'Dys_Blw_Thr', 'Dys_Abv_Thr', 'Good Days',
#        'Moderate Days', 'Unhealthy for Sensitive Groups Days',
#        'Unhealthy Days', 'Very Unhealthy Days', 'Hazardous Days', 'Max AQI',
#        '90th Percentile AQI', 'Median AQI', 'Days CO', 'Days NO2',
#        'Days Ozone', 'Days PM2.5', 'Days PM10'],
#       dtype='object')

# %%
data.groupby('Year') ['90th Percentile AQI'].mean()s
# Out:
# Year
# 1980     879.078431
# 1981     799.705882
# 1982     796.627451
# 1983     953.058824
# 1984     809.176471
# 1985     876.490196
# 1986     894.901961
# 1987    1035.568627
# 1988    1249.137255
# 1989    1030.764706
# 1990    1135.235294
# 1991    1235.568627
# 1992    1082.372549
# 1993    1209.372549
# 1994    1267.078431
# 1995    1353.862745
# 1996    1289.960784
# 1997    1331.666667
# 1998    1493.647059
# 1999    1698.274510
# 2000    1605.607843
# 2001    1646.215686
# 2002    1747.058824
# 2003    1567.921569
# 2004    1427.568627
# 2005    1638.509804
# 2006    1507.901961
# 2007    1560.823529
# 2008    1381.294118
# 2009    1234.568627
# 2010    1360.862745
# 2011    1367.980392
# 2012    1381.882353
# 2013    1195.196078
# 2014    1158.529412
# 2015    1166.686275
# 2016    1111.901961
# 2017    1135.392157
# 2018    1162.098039
# 2019    1056.921569
# 2020    1034.784314
# 2021    1131.176471
# 2022    1033.823529
# Name: 90th Percentile AQI, dtype: float64

# %%
data.groupby('Year') ['90th Percentile AQI'].mean().sort_values(ascending=False)
# Out:
# Year
# 2002    1747.058824
# 1999    1698.274510
# 2001    1646.215686
# 2005    1638.509804
# 2000    1605.607843
# 2003    1567.921569
# 2007    1560.823529
# 2006    1507.901961
# 1998    1493.647059
# 2004    1427.568627
# 2012    1381.882353
# 2008    1381.294118
# 2011    1367.980392
# 2010    1360.862745
# 1995    1353.862745
# 1997    1331.666667
# 1996    1289.960784
# 1994    1267.078431
# 1988    1249.137255
# 1991    1235.568627
# 2009    1234.568627
# 1993    1209.372549
# 2013    1195.196078
# 2015    1166.686275
# 2018    1162.098039
# 2014    1158.529412
# 2017    1135.392157
# 1990    1135.235294
# 2021    1131.176471
# 2016    1111.901961
# 1992    1082.372549
# 2019    1056.921569
# 1987    1035.568627
# 2020    1034.784314
# 2022    1033.823529
# 1989    1030.764706
# 1983     953.058824
# 1986     894.901961
# 1980     879.078431
# 1985     876.490196
# 1984     809.176471
# 1981     799.705882
# 1982     796.627451
# Name: 90th Percentile AQI, dtype: float64

# %%
sns.barplot(x='Year',y='90th Percentile AQI', data=data)
plt.title('90th Percentile AQI by year')
# Out:
# Text(0.5, 1.0, '90th Percentile AQI by year')

# %% [markdown]
# # 11.In which Year The Higthest Average Very Unhealthy Days

# %%
data.columns
# Out:
# Index(['Geo_Loc', 'Year', 'State', 'Pop_Est', 'TTL_Cnty', 'Cnty_Rpt',
#        'Dys_w_AQI', 'Dys_NM', 'Dys_Blw_Thr', 'Dys_Abv_Thr', 'Good Days',
#        'Moderate Days', 'Unhealthy for Sensitive Groups Days',
#        'Unhealthy Days', 'Very Unhealthy Days', 'Hazardous Days', 'Max AQI',
#        '90th Percentile AQI', 'Median AQI', 'Days CO', 'Days NO2',
#        'Days Ozone', 'Days PM2.5', 'Days PM10'],
#       dtype='object')

# %%
data.groupby('Year') ['Very Unhealthy Days'].mean().sort_values(ascending=False)
# Out:
# Year
# 1988    51.490196
# 1980    38.058824
# 1983    35.941176
# 1987    25.058824
# 1981    24.666667
# 1984    21.078431
# 1982    20.607843
# 1985    20.254902
# 1991    18.235294
# 1986    17.372549
# 1995    15.941176
# 1989    14.941176
# 1990    14.078431
# 1998    13.117647
# 2002    12.941176
# 1999    10.960784
# 1993    10.921569
# 1994    10.529412
# 1992     9.196078
# 1997     8.627451
# 1996     8.215686
# 2003     8.098039
# 2020     6.235294
# 2001     5.980392
# 2000     5.764706
# 2021     3.372549
# 2006     3.196078
# 2008     3.000000
# 2017     2.901961
# 2005     2.882353
# 2004     2.078431
# 2007     2.058824
# 2012     1.843137
# 2018     1.823529
# 2013     1.215686
# 2011     1.137255
# 2010     0.941176
# 2009     0.686275
# 2015     0.647059
# 2016     0.607843
# 2022     0.470588
# 2014     0.450980
# 2019     0.392157
# Name: Very Unhealthy Days, dtype: float64

# %%
sns.barplot(x='Year',y='Very Unhealthy Days', data=data)
plt.title('90th Percentile AQI by year')
# Out:
# Text(0.5, 1.0, '90th Percentile AQI by year')

# %% [markdown]
# # 12.Find The Average Rating For Each Percentile AQI

# %%
data.columns
# Out:
# Index(['Geo_Loc', 'Year', 'State', 'Pop_Est', 'TTL_Cnty', 'Cnty_Rpt',
#        'Dys_w_AQI', 'Dys_NM', 'Dys_Blw_Thr', 'Dys_Abv_Thr', 'Good Days',
#        'Moderate Days', 'Unhealthy for Sensitive Groups Days',
#        'Unhealthy Days', 'Very Unhealthy Days', 'Hazardous Days', 'Max AQI',
#        '90th Percentile AQI', 'Median AQI', 'Days CO', 'Days NO2',
#        'Days Ozone', 'Days PM2.5', 'Days PM10'],
#       dtype='object')

# %%
data.groupby('State')['90th Percentile AQI'].mean().sort_values(ascending=False)
# Out:
# State
# California              4932.255814
# Ohio                    3041.558140
# North Carolina          2808.697674
# Pennsylvania            2600.720930
# Texas                   2366.069767
# Indiana                 2345.674419
# Kentucky                2285.255814
# Virginia                2264.976744
# Wisconsin               1998.069767
# New York                1945.534884
# Michigan                1856.744186
# Tennessee               1757.348837
# Florida                 1728.697674
# Georgia                 1717.720930
# Illinois                1594.581395
# Colorado                1540.255814
# Louisiana               1467.116279
# South Carolina          1433.162791
# New Jersey              1420.744186
# Maryland                1277.813953
# Missouri                1202.372093
# Washington              1198.581395
# Alabama                 1185.883721
# Oklahoma                1070.395349
# Oregon                  1046.279070
# Minnesota                891.093023
# ...

# %% [markdown]
# # 13.Display Top 10 lengthy state

# %%
data.columns
# Out:
# Index(['Geo_Loc', 'Year', 'State', 'Pop_Est', 'TTL_Cnty', 'Cnty_Rpt',
#        'Dys_w_AQI', 'Dys_NM', 'Dys_Blw_Thr', 'Dys_Abv_Thr', 'Good Days',
#        'Moderate Days', 'Unhealthy for Sensitive Groups Days',
#        'Unhealthy Days', 'Very Unhealthy Days', 'Hazardous Days', 'Max AQI',
#        '90th Percentile AQI', 'Median AQI', 'Days CO', 'Days NO2',
#        'Days Ozone', 'Days PM2.5', 'Days PM10'],
#       dtype='object')

# %%
data.nlargest(10,'90th Percentile AQI')
# Out:
#                                             Geo_Loc  Year       State  \
# 820   POINT (-120.99999953799971 37.63864012300047)  1996  California
# 973   POINT (-120.99999953799971 37.63864012300047)  1999  California
# 1126  POINT (-120.99999953799971 37.63864012300047)  2002  California
# 922   POINT (-120.99999953799971 37.63864012300047)  1998  California
# 718   POINT (-120.99999953799971 37.63864012300047)  1994  California
# 412   POINT (-120.99999953799971 37.63864012300047)  1988  California
# 361   POINT (-120.99999953799971 37.63864012300047)  1987  California
# 1177  POINT (-120.99999953799971 37.63864012300047)  2003  California
# 1075  POINT (-120.99999953799971 37.63864012300047)  2001  California
# 769   POINT (-120.99999953799971 37.63864012300047)  1995  California
#
#        Pop_Est  TTL_Cnty  Cnty_Rpt  Dys_w_AQI  Dys_NM  Dys_Blw_Thr  \
# 820   32018834        58        56      17946    2550        15002
# ...
